# %% [markdown]
# # Fase 1: EDA Técnico - F1 Dataset

# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('f1_staging.db')
conn

# %%
tables = pd.read_sql_query("select name from sqlite_master WHERE type = 'table' order by name ", conn)
list_name = tables['name'].tolist()
list_name
# Out:
# ['circuits',
#  'constructor_results',
#  'constructor_standings',
#  'constructors',
#  'driver_standings',
#  'drivers',
#  'lap_times',
#  'pit_stops',
#  'qualifying',
#  'races',
#  'results',
#  'seasons',
#  'sprint_results',
#  'status']

# %%
def get_table(table_name):
    return pd.read_sql(f"SELECT * FROM {table_name}", conn)

# %%
results = get_table('results')
results.tail(5)
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 26754     26760    1144       825            210     20    14       16
# 26755     26761    1144       859            215     30    12       17
# 26756     26762    1144       822             15     77     9       \N
# 26757     26763    1144       861              3     43    20       \N
# 26758     26764    1144       815              9     11    10       \N
#
#       positionText  positionOrder  points  laps time milliseconds fastestLap  \
# 26754           16             16     0.0    57   \N           \N         57
# 26755           17             17     0.0    55   \N           \N         52
# 26756            R             18     0.0    30   \N           \N         14
# 26757            R             19     0.0    26   \N           \N          5
# 26758            R             20     0.0     0   \N           \N         \N
#
#       rank fastestLapTime fastestLapSpeed  statusId
# 26754    1       1:25.637         222.002        11
# 26755   12       1:28.751         214.212         5
# 26756   19       1:29.482         212.462       130
# 26757   17       1:29.411         212.631         5
# 26758    0             \N              \N         4

# %%
null_report = []
for table in list_name:
    df = get_table(table)
    n_counts = (df == '\\N').sum()
    n_counts = n_counts[n_counts > 0]
    for col, val in n_counts.items():
        null_report.append({'Tabla':table,'Columna':col,'Placeholder_Nulos': val})
df_nulls = pd.DataFrame(null_report)
print("Reporte de Pseudo-Nulos detectados:")
print(df_nulls)
# Out:
# Reporte de Pseudo-Nulos detectados:
#                   Tabla          Columna  Placeholder_Nulos
# 0   constructor_results           status              12608
# 1               drivers           number                802
# 2               drivers             code                757
# 3            qualifying               q1                156
# 4            qualifying               q2               4625
# 5            qualifying               q3               6819
# 6                 races             time                731
# 7                 races         fp1_date               1035
# 8                 races         fp1_time               1057
# 9                 races         fp2_date               1035
# 10                races         fp2_time               1057
# 11                races         fp3_date               1053
# 12                races         fp3_time               1072
# 13                races       quali_date               1035
# 14                races       quali_time               1057
# 15                races      sprint_date               1107
# 16                races      sprint_time               1110
# 17              results           number                  6
# 18              results         position              10953
# 19              results             time              19079
# 20              results     milliseconds              19079
# 21              results       fastestLap              18507
# 22              results             rank              18249
# 23              results   fastestLapTime              18507
# 24              results  fastestLapSpeed              18507
# 25       sprint_results         position                 15
# 26       sprint_results             time                 20
# 27       sprint_results     milliseconds                 20
# 28       sprint_results       fastestLap                  9
# 29       sprint_results   fastestLapTime                  9

# %%
nan_report = []
for table in list_name:
    df = get_table(table)
    nan_count = df.isna().sum()
    nan_count = nan_count[nan_count > 0]
    for col, val in nan_count.items():
        nan_report.append({'Table': table, 'Columna': col, 'Placeholder': val})
df_nan = pd.DataFrame(nan_report)
print("Reporte de Pseudo-Nulos detectados:")
print(df_nan)
# Out:
# Reporte de Pseudo-Nulos detectados:
#         Table Columna  Placeholder
# 0  qualifying      q2           22
# 1  qualifying      q3           46

# %%
typ_report = []

for table in list_name:
    df = get_table(table)
    typ_count = df.dtypes
    for col, val in typ_count.items():
        typ_report.append({'Table': table, 'Columna': col, 'Tipo_dato': str(val)})
df_typ = pd.DataFrame(typ_report)
print("Reporte tipo de datos detectados:")
print(df_typ)
# Out:
# Reporte tipo de datos detectados:
#               Table         Columna Tipo_dato
# 0          circuits       circuitId     int64
# 1          circuits      circuitRef    object
# 2          circuits            name    object
# 3          circuits        location    object
# 4          circuits         country    object
# ..              ...             ...       ...
# 115  sprint_results      fastestLap    object
# 116  sprint_results  fastestLapTime    object
# 117  sprint_results        statusId     int64
# 118          status        statusId     int64
# 119          status          status    object
#
# [120 rows x 3 columns]

# %%
df_sospechosas = df_typ[df_typ['Tipo_dato'] == 'object']
print(df_sospechosas)
# Out:
#                      Table          Columna Tipo_dato
# 1                 circuits       circuitRef    object
# 2                 circuits             name    object
# 3                 circuits         location    object
# 4                 circuits          country    object
# 8                 circuits              url    object
# 13     constructor_results           status    object
# 19   constructor_standings     positionText    object
# 22            constructors   constructorRef    object
# 23            constructors             name    object
# 24            constructors      nationality    object
# 25            constructors              url    object
# 31        driver_standings     positionText    object
# 34                 drivers        driverRef    object
# 35                 drivers           number    object
# 36                 drivers             code    object
# 37                 drivers         forename    object
# 38                 drivers          surname    object
# 39                 drivers              dob    object
# 40                 drivers      nationality    object
# 41                 drivers              url    object
# 46               lap_times             time    object
# 52               pit_stops             time    object
# 53               pit_stops         duration    object
# 61              qualifying               q1    object
# 62              qualifying               q2    object
# 63              qualifying               q3    object
# 68                   races             name    object
# 69                   races             date    object
# 70                   races             time    object
# 71                   races              url    object
# 72                   races         fp1_date    object
# 73                   races         fp1_time    object
# 74                   races         fp2_date    object
# 75                   races         fp2_time    object
# 76                   races         fp3_date    object
# 77                   races         fp3_time    object
# 78                   races       quali_date    object
# 79                   races       quali_time    object
# 80                   races      sprint_date    object
# 81                   races      sprint_time    object
# 86                 results           number    object
# 88                 results         position    object
# 89                 results     positionText    object
# 93                 results             time    object
# 94                 results     milliseconds    object
# 95                 results       fastestLap    object
# 96                 results             rank    object
# 97                 results   fastestLapTime    object
# 98                 results  fastestLapSpeed    object
# 101                seasons              url    object
# 108         sprint_results         position    object
# 109         sprint_results     positionText    object
# 113         sprint_results             time    object
# 114         sprint_results     milliseconds    object
# 115         sprint_results       fastestLap    object
# 116         sprint_results   fastestLapTime    object
# 119                 status           status    object

# %%
dup_report = []
for table in list_name:
    df = get_table(table)
    n_duplicados = df.duplicated().sum()
    if n_duplicados > 0:
        dup_report.append({'Tabla': table, 'Filas_Duplicadas': n_duplicados})

df_dups = pd.DataFrame(dup_report)
dup_report
# Out:
# []

# %%
## RESUMEN
health_report = []

for table in list_name:
    df = get_table(table)

    n_nans = df.isna().sum().sum()
    n_pseudos = (df == '\\N').sum().sum()
    n_dups = df.duplicated().sum()
    cols_obj = (df.dtypes == 'object').sum()
    
    health_report.append({
        'Tabla': table,
        'Filas': len(df),
        'Columnas': len(df.columns),
        'Nulos_Reales': n_nans,
        'Pseudo_Nulos': n_pseudos,
        'Duplicados': n_dups,
        'Cols_Texto': cols_obj
    })

df_health = pd.DataFrame(health_report)
print("Matriz de Salud de los Datos:")
display(df_health)
# Out:
# Matriz de Salud de los Datos:
#                     Tabla   Filas  Columnas  Nulos_Reales  Pseudo_Nulos  \
# 0                circuits      77         9             0             0
# 1     constructor_results   12625         5             0         12608
# 2   constructor_standings   13391         7             0             0
# 3            constructors     212         5             0             0
# 4        driver_standings   34863         7             0             0
# 5                 drivers     861         9             0          1559
# 6               lap_times  589081         6             0             0
# 7               pit_stops   11371         7             0             0
# 8              qualifying   10494         9            68         11600
# 9                   races    1125        18             0         11349
# 10                results   26759        18             0        122887
# 11                seasons      75         2             0             0
# 12         sprint_results     360        16             0            73
# 13                 status     139         2             0             0
#
#     Duplicados  Cols_Texto
# 0            0           5
# 1            0           1
# 2            0           1
# 3            0           4
# 4            0           1
# 5            0           8
# 6            0           1
# 7            0           2
# 8            0           3
# 9            0          14
# 10           0           9
# 11           0           1
# 12           0           6
# 13           0           1
